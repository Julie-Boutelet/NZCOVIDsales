# %%
import pandas as pd
df= pd.read_csv('effectscovid.csv')
df.loc[(df['Year'] == 2019.0)]
# Out:
#        Direction    Year        Date    Weekday Country Commodity  \
# 64047    Exports  2019.0  01/01/2019    Tuesday     All       All
# 64048    Exports  2019.0  02/01/2019  Wednesday     All       All
# 64049    Exports  2019.0  03/01/2019   Thursday     All       All
# 64050    Exports  2019.0  04/01/2019     Friday     All       All
# 64051    Exports  2019.0  05/01/2019   Saturday     All       All
# ...          ...     ...         ...        ...     ...       ...
# 80059  Reimports  2019.0  26/12/2019   Thursday     All       All
# 80060  Reimports  2019.0  27/12/2019     Friday     All       All
# 80061  Reimports  2019.0  29/12/2019     Sunday     All       All
# 80062  Reimports  2019.0  30/12/2019     Monday     All       All
# 80063  Reimports  2019.0  31/12/2019    Tuesday     All       All
#
#       Transport_Mode Measure        Value   Cumulative
# 64047            All       $  113000000.0  113000000.0
# 64048            All       $   51000000.0  164000000.0
# ...
